# %% [markdown]
# # The code below gets a list of all economists who have an article on wikipedia. It uses requests to access the page and BeautifulSoup to parse the page.

# %% [markdown]
# Import all libraries

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import time
from urllib.parse import quote

# %% [markdown]
# The list_url url has all economists listen in the alphabetical order

# %%
main_url = "https://en.wikipedia.org"
list_url = "https://en.wikipedia.org/wiki/List_of_economists"

# %% [markdown]
# Headers had to be used to get a 200 response status, without a header response was 304.

# %%
headers = {"User-Agent": "SohaKhan/1.0 (sk131@wellesley.edu) CourseProject/CS234; respectful academic use"}
response = requests.get(list_url, headers=headers)
domTree = BS(response.text, "html.parser")

# %% [markdown]
# All names are listed under div-col

# %%
sections = domTree.find_all("div", class_="div-col")

# %%
economists = []

for sec in sections:
    for li in sec.find_all("li"):
        # Only take THE FIRST <a> — economist name
        first_link = li.find("a")
        if not first_link:
            continue

        href = first_link.get("href", "")
        
        # ensure it's a proper Wikipedia article
        if href.startswith("/wiki/") and not ":" in href:
            economists.append({
                "name": first_link.text.strip(),
                "article_url": "https://en.wikipedia.org" + href
            })

len(economists)
# Out:
# 1239

# %% [markdown]
# Compare len of names to the length of unique names in the list to make sure no name is duplicated

# %%
names = [e["name"] for e in economists]
len(names), len(set(names))
# Out:
# (1239, 1239)

# %%
economists
# Out:
# [{'name': 'Edith Abbott',
#   'article_url': 'https://en.wikipedia.org/wiki/Edith_Abbott'},
#  {'name': 'Daron Acemoglu',
#   'article_url': 'https://en.wikipedia.org/wiki/Daron_Acemoglu'},
#  {'name': 'Nicola Acocella',
#   'article_url': 'https://en.wikipedia.org/wiki/Nicola_Acocella'},
#  {'name': 'Zoltan Acs',
#   'article_url': 'https://en.wikipedia.org/wiki/Zoltan_Acs'},
#  {'name': 'Henry Carter Adams',
#   'article_url': 'https://en.wikipedia.org/wiki/Henry_Carter_Adams'},
#  {'name': 'Walter Adams',
#   'article_url': 'https://en.wikipedia.org/wiki/Walter_Adams_(economist)'},
#  {'name': 'Philippe Aghion',
#   'article_url': 'https://en.wikipedia.org/wiki/Philippe_Aghion'},
#  {'name': 'Montek Singh Ahluwalia',
#   'article_url': 'https://en.wikipedia.org/wiki/Montek_Singh_Ahluwalia'},
#  {'name': 'Qazi Kholiquzzaman Ahmad',
#   'article_url': 'https://en.wikipedia.org/wiki/Qazi_Kholiquzzaman_Ahmad'},
#  {'name': 'George Akerlof',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Akerlof'},
#  {'name': 'Armen Alchian',
#   'article_url': 'https://en.wikipedia.org/wiki/Armen_Alchian'},
#  {'name': 'Alberto Alesina',
#   'article_url': 'https://en.wikipedia.org/wiki/Alberto_Alesina'},
#  {'name': 'Sadie Alexander',
#   'article_url': 'https://en.wikipedia.org/wiki/Sadie_Alexander'},
#  {'name': 'Sidney S. Alexander',
#   'article_url': 'https://en.wikipedia.org/wiki/Sidney_S._Alexander'},
#  {'name': 'Maurice Allais',
#   'article_url': 'https://en.wikipedia.org/wiki/Maurice_Allais'},
#  {'name': 'Franklin Allen',
#   'article_url': 'https://en.wikipedia.org/wiki/Franklin_Allen'},
#  {'name': 'R. G. D. Allen',
#   'article_url': 'https://en.wikipedia.org/wiki/R._G._D._Allen'},
#  {'name': 'Gar Alperovitz',
#   'article_url': 'https://en.wikipedia.org/wiki/Gar_Alperovitz'},
#  {'name': 'Lee J. Alston',
#   'article_url': 'https://en.wikipedia.org/wiki/Lee_J._Alston'},
#  {'name': 'Elisabeth Altmann-Gottheiner',
#   'article_url': 'https://en.wikipedia.org/wiki/Elisabeth_Altmann-Gottheiner'},
#  {'name': 'Fernando Alvarez',
#   'article_url': 'https://en.wikipedia.org/wiki/Fernando_Alvarez_(economist)'},
#  {'name': 'Jack Amariglio',
#   'article_url': 'https://en.wikipedia.org/wiki/Jack_Amariglio'},
#  {'name': 'B. R. Ambedkar',
#   'article_url': 'https://en.wikipedia.org/wiki/B._R._Ambedkar'},
#  {'name': 'Takeshi Amemiya',
#   'article_url': 'https://en.wikipedia.org/wiki/Takeshi_Amemiya'},
#  {'name': 'Samir Amin',
#   'article_url': 'https://en.wikipedia.org/wiki/Samir_Amin'},
#  {'name': 'Georges Anderla',
#   'article_url': 'https://en.wikipedia.org/wiki/Georges_Anderla'},
#  {'name': 'W. H. Locke Anderson',
#   'article_url': 'https://en.wikipedia.org/wiki/W._H._Locke_Anderson'},
#  {'name': 'Donald Andrews',
#   'article_url': 'https://en.wikipedia.org/wiki/Donald_Andrews'},
#  {'name': 'George-Marios Angeletos',
#   'article_url': 'https://en.wikipedia.org/wiki/George-Marios_Angeletos'},
#  {'name': 'Norman Angell',
#   'article_url': 'https://en.wikipedia.org/wiki/Norman_Angell'},
#  {'name': 'Joshua Angrist',
#   'article_url': 'https://en.wikipedia.org/wiki/Joshua_Angrist'},
#  {'name': 'Kofi Annan',
#   'article_url': 'https://en.wikipedia.org/wiki/Kofi_Annan'},
#  {'name': 'Masahiko Aoki',
#   'article_url': 'https://en.wikipedia.org/wiki/Masahiko_Aoki'},
#  {'name': 'Thomas Aquinas',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_Aquinas'},
#  {'name': 'Luis Arce',
#   'article_url': 'https://en.wikipedia.org/wiki/Luis_Arce'},
#  {'name': 'Pérsio Arida',
#   'article_url': 'https://en.wikipedia.org/wiki/P%C3%A9rsio_Arida'},
#  {'name': 'Dan Ariely',
#   'article_url': 'https://en.wikipedia.org/wiki/Dan_Ariely'},
#  {'name': 'Aristotle',
#   'article_url': 'https://en.wikipedia.org/wiki/Aristotle'},
#  {'name': 'Heinz Arndt',
#   'article_url': 'https://en.wikipedia.org/wiki/Heinz_Arndt'},
#  {'name': 'Kenneth Arrow',
#   'article_url': 'https://en.wikipedia.org/wiki/Kenneth_Arrow'},
#  {'name': 'Gloria Macapagal Arroyo',
#   'article_url': 'https://en.wikipedia.org/wiki/Gloria_Macapagal_Arroyo'},
#  {'name': 'Enrique R. Arzac',
#   'article_url': 'https://en.wikipedia.org/wiki/Enrique_R._Arzac'},
#  {'name': 'Orley Ashenfelter',
#   'article_url': 'https://en.wikipedia.org/wiki/Orley_Ashenfelter'},
#  {'name': 'William Ashley',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Ashley_(economic_historian)'},
#  {'name': 'Cliff Asness',
#   'article_url': 'https://en.wikipedia.org/wiki/Cliff_Asness'},
#  {'name': 'Jeremy Atack',
#   'article_url': 'https://en.wikipedia.org/wiki/Jeremy_Atack'},
#  {'name': 'Susan Athey',
#   'article_url': 'https://en.wikipedia.org/wiki/Susan_Athey'},
#  {'name': 'Anthony Barnes Atkinson',
#   'article_url': 'https://en.wikipedia.org/wiki/Anthony_Barnes_Atkinson'},
#  {'name': 'Orazio Attanasio',
#   'article_url': 'https://en.wikipedia.org/wiki/Orazio_Attanasio'},
#  {'name': 'Thomas Attwood',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_Attwood_(economist)'},
#  {'name': 'David B. Audretsch',
#   'article_url': 'https://en.wikipedia.org/wiki/David_B._Audretsch'},
#  {'name': 'Leonardo Auernheimer',
#   'article_url': 'https://en.wikipedia.org/wiki/Leonardo_Auernheimer'},
#  {'name': 'Robert Aumann',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Aumann'},
#  {'name': 'David Autor',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Autor'},
#  {'name': 'George Ayittey',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Ayittey'},
#  {'name': 'Clarence Ayres',
#   'article_url': 'https://en.wikipedia.org/wiki/Clarence_Ayres'},
#  {'name': 'Martín de Azpilcueta',
#   'article_url': 'https://en.wikipedia.org/wiki/Mart%C3%ADn_de_Azpilcueta'},
#  {'name': 'Ali Babacan',
#   'article_url': 'https://en.wikipedia.org/wiki/Ali_Babacan'},
#  {'name': 'Roger Babson',
#   'article_url': 'https://en.wikipedia.org/wiki/Roger_Babson'},
#  {'name': 'Lawrence Bacow',
#   'article_url': 'https://en.wikipedia.org/wiki/Lawrence_Bacow'},
#  {'name': 'Louis Bachelier',
#   'article_url': 'https://en.wikipedia.org/wiki/Louis_Bachelier'},
#  {'name': 'Hans-Georg Backhaus',
#   'article_url': 'https://en.wikipedia.org/wiki/Hans-Georg_Backhaus'},
#  {'name': 'Roger Backhouse',
#   'article_url': 'https://en.wikipedia.org/wiki/Roger_Backhouse_(economist)'},
#  {'name': 'Walter Bagehot',
#   'article_url': 'https://en.wikipedia.org/wiki/Walter_Bagehot'},
#  {'name': 'Nikolai Baibakov',
#   'article_url': 'https://en.wikipedia.org/wiki/Nikolai_Baibakov'},
#  {'name': 'Joe S. Bain',
#   'article_url': 'https://en.wikipedia.org/wiki/Joe_S._Bain'},
#  {'name': 'Dean Baker',
#   'article_url': 'https://en.wikipedia.org/wiki/Dean_Baker'},
#  {'name': 'E. Wight Bakke',
#   'article_url': 'https://en.wikipedia.org/wiki/E._Wight_Bakke'},
#  {'name': 'Mikhail Bakunin',
#   'article_url': 'https://en.wikipedia.org/wiki/Mikhail_Bakunin'},
#  {'name': 'Leszek Balcerowicz',
#   'article_url': 'https://en.wikipedia.org/wiki/Leszek_Balcerowicz'},
#  {'name': 'Emily Greene Balch',
#   'article_url': 'https://en.wikipedia.org/wiki/Emily_Greene_Balch'},
#  {'name': 'Richard Baldwin',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Baldwin_(economist)'},
#  {'name': 'Sir James Ball',
#   'article_url': 'https://en.wikipedia.org/wiki/James_Ball_(economist)'},
#  {'name': 'Ludwig Bamberger',
#   'article_url': 'https://en.wikipedia.org/wiki/Ludwig_Bamberger'},
#  {'name': 'Abhijit Banerjee',
#   'article_url': 'https://en.wikipedia.org/wiki/Abhijit_Banerjee'},
#  {'name': 'Pratima Bansal',
#   'article_url': 'https://en.wikipedia.org/wiki/Pratima_Bansal'},
#  {'name': 'Paul A. Baran',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_A._Baran'},
#  {'name': 'Pranab Bardhan',
#   'article_url': 'https://en.wikipedia.org/wiki/Pranab_Bardhan'},
#  {'name': 'Alexandru Bârlădeanu',
#   'article_url': 'https://en.wikipedia.org/wiki/Alexandru_B%C3%A2rl%C4%83deanu'},
#  {'name': 'William A. Barnett',
#   'article_url': 'https://en.wikipedia.org/wiki/William_A._Barnett'},
#  {'name': 'Enrico Barone',
#   'article_url': 'https://en.wikipedia.org/wiki/Enrico_Barone'},
#  {'name': 'Nicholas Barr',
#   'article_url': 'https://en.wikipedia.org/wiki/Nicholas_Barr'},
#  {'name': 'Raymond Barre',
#   'article_url': 'https://en.wikipedia.org/wiki/Raymond_Barre'},
#  {'name': 'Robert Barro',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Barro'},
#  {'name': 'Yoram Barzel',
#   'article_url': 'https://en.wikipedia.org/wiki/Yoram_Barzel'},
#  {'name': 'Frédéric Bastiat',
#   'article_url': 'https://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Bastiat'},
#  {'name': 'Kaushik Basu',
#   'article_url': 'https://en.wikipedia.org/wiki/Kaushik_Basu'},
#  {'name': 'Ratan Lal Basu',
#   'article_url': 'https://en.wikipedia.org/wiki/Ratan_Lal_Basu'},
#  {'name': 'Ravi Batra',
#   'article_url': 'https://en.wikipedia.org/wiki/Ravi_Batra'},
#  {'name': 'Peter Thomas Bauer',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Thomas_Bauer'},
#  {'name': 'William Baumol',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Baumol'},
#  {'name': 'Mahamudu Bawumia',
#   'article_url': 'https://en.wikipedia.org/wiki/Mahamudu_Bawumia'},
#  {'name': 'Eugen von Böhm-Bawerk',
#   'article_url': 'https://en.wikipedia.org/wiki/Eugen_von_B%C3%B6hm-Bawerk'},
#  {'name': 'Robert Dudley Baxter',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Dudley_Baxter'},
#  {'name': 'Michael Baye',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Baye'},
#  {'name': 'Charlie Bean',
#   'article_url': 'https://en.wikipedia.org/wiki/Charlie_Bean_(economist)'},
#  {'name': 'Gary Becker',
#   'article_url': 'https://en.wikipedia.org/wiki/Gary_Becker'},
#  {'name': 'Yoram Ben-Porat',
#   'article_url': 'https://en.wikipedia.org/wiki/Yoram_Ben-Porat'},
#  {'name': 'Jeremy Bentham',
#   'article_url': 'https://en.wikipedia.org/wiki/Jeremy_Bentham'},
#  {'name': 'Dwayne Benjamin',
#   'article_url': 'https://en.wikipedia.org/wiki/Dwayne_Benjamin_(economist)'},
#  {'name': 'Barbara Bergmann',
#   'article_url': 'https://en.wikipedia.org/wiki/Barbara_Bergmann'},
#  {'name': 'C. Fred Bergsten',
#   'article_url': 'https://en.wikipedia.org/wiki/C._Fred_Bergsten'},
#  {'name': 'Rex Bergstrom',
#   'article_url': 'https://en.wikipedia.org/wiki/Rex_Bergstrom'},
#  {'name': 'Adolf Berle',
#   'article_url': 'https://en.wikipedia.org/wiki/Adolf_Berle'},
#  {'name': 'Ben Bernanke',
#   'article_url': 'https://en.wikipedia.org/wiki/Ben_Bernanke'},
#  {'name': 'Jared Bernstein',
#   'article_url': 'https://en.wikipedia.org/wiki/Jared_Bernstein'},
#  {'name': 'Marianne Bertrand',
#   'article_url': 'https://en.wikipedia.org/wiki/Marianne_Bertrand'},
#  {'name': 'Tim Besley',
#   'article_url': 'https://en.wikipedia.org/wiki/Tim_Besley'},
#  {'name': 'Charles Bettelheim',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Bettelheim'},
#  {'name': 'William Beveridge',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Beveridge'},
#  {'name': 'Truman Bewley',
#   'article_url': 'https://en.wikipedia.org/wiki/Truman_Bewley'},
#  {'name': 'Jagdish Bhagwati',
#   'article_url': 'https://en.wikipedia.org/wiki/Jagdish_Bhagwati'},
#  {'name': 'Debapriya Bhattacharya',
#   'article_url': 'https://en.wikipedia.org/wiki/Debapriya_Bhattacharya'},
#  {'name': 'Mark Bils',
#   'article_url': 'https://en.wikipedia.org/wiki/Mark_Bils'},
#  {'name': 'Nancy Birdsall',
#   'article_url': 'https://en.wikipedia.org/wiki/Nancy_Birdsall'},
#  {'name': 'Kenneth Binmore',
#   'article_url': 'https://en.wikipedia.org/wiki/Kenneth_Binmore'},
#  {'name': 'Mette Koefoed Bjørnsen',
#   'article_url': 'https://en.wikipedia.org/wiki/Mette_Koefoed_Bj%C3%B8rnsen'},
#  {'name': 'William K. Black',
#   'article_url': 'https://en.wikipedia.org/wiki/William_K._Black'},
#  {'name': 'Fischer Black',
#   'article_url': 'https://en.wikipedia.org/wiki/Fischer_Black'},
#  {'name': 'William Blake',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Blake_(economist)'},
#  {'name': 'Olivier Blanchard',
#   'article_url': 'https://en.wikipedia.org/wiki/Olivier_Blanchard'},
#  {'name': 'Rebecca Blank',
#   'article_url': 'https://en.wikipedia.org/wiki/Rebecca_Blank'},
#  {'name': 'Francine D. Blau',
#   'article_url': 'https://en.wikipedia.org/wiki/Francine_D._Blau'},
#  {'name': 'Knut Blind',
#   'article_url': 'https://en.wikipedia.org/wiki/Knut_Blind'},
#  {'name': 'Alan Blinder',
#   'article_url': 'https://en.wikipedia.org/wiki/Alan_Blinder'},
#  {'name': 'Walter Block',
#   'article_url': 'https://en.wikipedia.org/wiki/Walter_Block'},
#  {'name': 'Barry Bluestone',
#   'article_url': 'https://en.wikipedia.org/wiki/Barry_Bluestone'},
#  {'name': 'John Blundell',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Blundell_(economist)'},
#  {'name': 'Richard Blundell',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Blundell'},
#  {'name': 'Jean Bodin',
#   'article_url': 'https://en.wikipedia.org/wiki/Jean_Bodin'},
#  {'name': 'Tito Boeri',
#   'article_url': 'https://en.wikipedia.org/wiki/Tito_Boeri'},
#  {'name': 'Peter J. Boettke',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_J._Boettke'},
#  {'name': 'Michele Boldrin',
#   'article_url': 'https://en.wikipedia.org/wiki/Michele_Boldrin'},
#  {'name': 'Tim Bollerslev',
#   'article_url': 'https://en.wikipedia.org/wiki/Tim_Bollerslev'},
#  {'name': 'Matilde Bombardini',
#   'article_url': 'https://en.wikipedia.org/wiki/Matilde_Bombardini'},
#  {'name': 'Murray Bookchin',
#   'article_url': 'https://en.wikipedia.org/wiki/Murray_Bookchin'},
#  {'name': 'Korkut Boratav',
#   'article_url': 'https://en.wikipedia.org/wiki/Korkut_Boratav'},
#  {'name': 'George Borjas',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Borjas'},
#  {'name': 'Michael Boskin',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Boskin'},
#  {'name': 'Giovanni Botero',
#   'article_url': 'https://en.wikipedia.org/wiki/Giovanni_Botero'},
#  {'name': 'O. Fred Boucke',
#   'article_url': 'https://en.wikipedia.org/wiki/O._Fred_Boucke'},
#  {'name': 'Kenneth E. Boulding',
#   'article_url': 'https://en.wikipedia.org/wiki/Kenneth_E._Boulding'},
#  {'name': 'Heather Boushey',
#   'article_url': 'https://en.wikipedia.org/wiki/Heather_Boushey'},
#  {'name': 'Samuel Bowles',
#   'article_url': 'https://en.wikipedia.org/wiki/Samuel_Bowles_(economist)'},
#  {'name': 'David Boyle',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Boyle_(author)'},
#  {'name': 'William Brainard',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Brainard'},
#  {'name': 'James Brander',
#   'article_url': 'https://en.wikipedia.org/wiki/James_Brander'},
#  {'name': 'Avishay Braverman',
#   'article_url': 'https://en.wikipedia.org/wiki/Avishay_Braverman'},
#  {'name': 'Harry Braverman',
#   'article_url': 'https://en.wikipedia.org/wiki/Harry_Braverman'},
#  {'name': 'John Francis Bray',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Francis_Bray'},
#  {'name': 'Richard A. Brealey',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_A._Brealey'},
#  {'name': 'William Breit',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Breit'},
#  {'name': 'Robert Brenner',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Brenner'},
#  {'name': 'George Ignatius Brizan',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Brizan'},
#  {'name': 'Martin Browning',
#   'article_url': 'https://en.wikipedia.org/wiki/Martin_Browning'},
#  {'name': 'Sylvie Brunel',
#   'article_url': 'https://en.wikipedia.org/wiki/Sylvie_Brunel'},
#  {'name': 'Markus Brunnermeier',
#   'article_url': 'https://en.wikipedia.org/wiki/Markus_Brunnermeier'},
#  {'name': 'Michael Bruno',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Bruno_(economist)'},
#  {'name': 'Erik Brynjolfsson',
#   'article_url': 'https://en.wikipedia.org/wiki/Erik_Brynjolfsson'},
#  {'name': 'James M. Buchanan',
#   'article_url': 'https://en.wikipedia.org/wiki/James_M._Buchanan'},
#  {'name': 'Alan Budd',
#   'article_url': 'https://en.wikipedia.org/wiki/Alan_Budd'},
#  {'name': 'Willem Buiter',
#   'article_url': 'https://en.wikipedia.org/wiki/Willem_Buiter'},
#  {'name': 'Sergei Bulgakov',
#   'article_url': 'https://en.wikipedia.org/wiki/Sergei_Bulgakov'},
#  {'name': 'Edmund Burke',
#   'article_url': 'https://en.wikipedia.org/wiki/Edmund_Burke'},
#  {'name': 'Paul Burkett',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Burkett'},
#  {'name': 'Ricardo J. Caballero',
#   'article_url': 'https://en.wikipedia.org/wiki/Ricardo_J._Caballero'},
#  {'name': 'Vince Cable',
#   'article_url': 'https://en.wikipedia.org/wiki/Vince_Cable'},
#  {'name': 'Federico Caffè',
#   'article_url': 'https://en.wikipedia.org/wiki/Federico_Caff%C3%A8'},
#  {'name': 'Phillip D. Cagan',
#   'article_url': 'https://en.wikipedia.org/wiki/Phillip_D._Cagan'},
#  {'name': 'John Elliot Cairnes',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Elliott_Cairnes'},
#  {'name': 'Guillermo Calvo',
#   'article_url': 'https://en.wikipedia.org/wiki/Guillermo_Calvo'},
#  {'name': 'John Y. Campbell',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Y._Campbell'},
#  {'name': 'Colin Camerer',
#   'article_url': 'https://en.wikipedia.org/wiki/Colin_Camerer'},
#  {'name': 'Lisa Cameron',
#   'article_url': 'https://en.wikipedia.org/wiki/Lisa_Cameron_(economist)'},
#  {'name': 'Stephen Cameron',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephen_Cameron'},
#  {'name': 'Richard Cantillon',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Cantillon'},
#  {'name': 'Edwin Cannan',
#   'article_url': 'https://en.wikipedia.org/wiki/Edwin_Cannan'},
#  {'name': 'Bryan Caplan',
#   'article_url': 'https://en.wikipedia.org/wiki/Bryan_Caplan'},
#  {'name': 'David Card',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Card'},
#  {'name': 'Matias D. Cattaneo',
#   'article_url': 'https://en.wikipedia.org/wiki/Matias_D._Cattaneo'},
#  {'name': 'Henry Charles Carey',
#   'article_url': 'https://en.wikipedia.org/wiki/Henry_Charles_Carey'},
#  {'name': 'Mark Carney',
#   'article_url': 'https://en.wikipedia.org/wiki/Mark_Carney'},
#  {'name': 'Kevin Carson',
#   'article_url': 'https://en.wikipedia.org/wiki/Kevin_Carson'},
#  {'name': 'Richard Carson',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Carson'},
#  {'name': 'Agustín Carstens',
#   'article_url': 'https://en.wikipedia.org/wiki/Agust%C3%ADn_Carstens'},
#  {'name': 'Anne P. Carter',
#   'article_url': 'https://en.wikipedia.org/wiki/Anne_Carter_(economist)'},
#  {'name': 'David Cass',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Cass'},
#  {'name': 'Gustav Cassel',
#   'article_url': 'https://en.wikipedia.org/wiki/Gustav_Cassel'},
#  {'name': 'Attilio Celant',
#   'article_url': 'https://en.wikipedia.org/wiki/Attilio_Celant'},
#  {'name': 'Seweryn Chajtman',
#   'article_url': 'https://en.wikipedia.org/wiki/Seweryn_Chajtman'},
#  {'name': 'Thomas Chalmers',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_Chalmers'},
#  {'name': 'Frank J. Chaloupka',
#   'article_url': 'https://en.wikipedia.org/wiki/Frank_J._Chaloupka'},
#  {'name': 'Edward Hastings Chamberlin',
#   'article_url': 'https://en.wikipedia.org/wiki/Edward_Hastings_Chamberlin'},
#  {'name': 'Neil W. Chamberlain',
#   'article_url': 'https://en.wikipedia.org/wiki/Neil_W._Chamberlain'},
#  {'name': 'Alfred D. Chandler, Jr.',
#   'article_url': 'https://en.wikipedia.org/wiki/Alfred_D._Chandler,_Jr.'},
#  {'name': 'Ha-Joon Chang',
#   'article_url': 'https://en.wikipedia.org/wiki/Ha-Joon_Chang'},
#  {'name': 'V. V. Chari',
#   'article_url': 'https://en.wikipedia.org/wiki/V._V._Chari'},
#  {'name': 'François Chesnais',
#   'article_url': 'https://en.wikipedia.org/wiki/Fran%C3%A7ois_Chesnais'},
#  {'name': 'Raj Chetty',
#   'article_url': 'https://en.wikipedia.org/wiki/Raj_Chetty'},
#  {'name': 'Steven N. S. Cheung',
#   'article_url': 'https://en.wikipedia.org/wiki/Steven_N._S._Cheung'},
#  {'name': 'Ajay Chhibber',
#   'article_url': 'https://en.wikipedia.org/wiki/Ajay_Chhibber'},
#  {'name': 'Graciela Chichilnisky',
#   'article_url': 'https://en.wikipedia.org/wiki/Graciela_Chichilnisky'},
#  {'name': 'Victoria Chick',
#   'article_url': 'https://en.wikipedia.org/wiki/Victoria_Chick'},
#  {'name': 'Josiah Child',
#   'article_url': 'https://en.wikipedia.org/wiki/Josiah_Child'},
#  {'name': 'Menzie Chinn',
#   'article_url': 'https://en.wikipedia.org/wiki/Menzie_Chinn'},
#  {'name': 'Lawrence J. Christiano',
#   'article_url': 'https://en.wikipedia.org/wiki/Lawrence_J._Christiano'},
#  {'name': 'Anders Chydenius',
#   'article_url': 'https://en.wikipedia.org/wiki/Anders_Chydenius'},
#  {'name': 'Richard Clarida',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Clarida'},
#  {'name': 'Colin Clark',
#   'article_url': 'https://en.wikipedia.org/wiki/Colin_Clark_(economist)'},
#  {'name': 'Gregory Clark',
#   'article_url': 'https://en.wikipedia.org/wiki/Gregory_Clark_(economist)'},
#  {'name': 'John Bates Clark',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Bates_Clark'},
#  {'name': 'John Maurice Clark',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Maurice_Clark'},
#  {'name': 'William D. Clark',
#   'article_url': 'https://en.wikipedia.org/wiki/William_D._Clark'},
#  {'name': 'Harry Cleaver',
#   'article_url': 'https://en.wikipedia.org/wiki/Harry_Cleaver'},
#  {'name': 'Michael Clemens',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Clemens'},
#  {'name': 'Ronald Coase',
#   'article_url': 'https://en.wikipedia.org/wiki/Ronald_Coase'},
#  {'name': 'Warren Coats',
#   'article_url': 'https://en.wikipedia.org/wiki/Warren_Coats'},
#  {'name': 'John H. Cochrane',
#   'article_url': 'https://en.wikipedia.org/wiki/John_H._Cochrane'},
#  {'name': 'Paul Cockshott',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Cockshott'},
#  {'name': 'Luc Coene',
#   'article_url': 'https://en.wikipedia.org/wiki/Luc_Coene'},
#  {'name': 'Jean-Baptiste Colbert',
#   'article_url': 'https://en.wikipedia.org/wiki/Jean-Baptiste_Colbert'},
#  {'name': 'Paul Collier',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Collier'},
#  {'name': 'John R. Commons',
#   'article_url': 'https://en.wikipedia.org/wiki/John_R._Commons'},
#  {'name': 'Auguste Comte',
#   'article_url': 'https://en.wikipedia.org/wiki/Auguste_Comte'},
#  {'name': 'Marquis de Condorcet',
#   'article_url': 'https://en.wikipedia.org/wiki/Marquis_de_Condorcet'},
#  {'name': 'Tim Congdon',
#   'article_url': 'https://en.wikipedia.org/wiki/Tim_Congdon'},
#  {'name': 'Alfred Haskell Conrad',
#   'article_url': 'https://en.wikipedia.org/wiki/Alfred_Haskell_Conrad'},
#  {'name': 'Hugh E. Conway',
#   'article_url': 'https://en.wikipedia.org/wiki/Hugh_E._Conway'},
#  {'name': 'Thomas F. Cooley',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_F._Cooley'},
#  {'name': 'Richard N. Cooper',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_N._Cooper'},
#  {'name': 'Russell W. Cooper',
#   'article_url': 'https://en.wikipedia.org/wiki/Russell_W._Cooper'},
#  {'name': 'Antoine Augustin Cournot',
#   'article_url': 'https://en.wikipedia.org/wiki/Antoine_Augustin_Cournot'},
#  {'name': 'Nicolaus Copernicus',
#   'article_url': 'https://en.wikipedia.org/wiki/Nicolaus_Copernicus'},
#  {'name': 'Carol Corrado',
#   'article_url': 'https://en.wikipedia.org/wiki/Carol_Corrado'},
#  {'name': 'Dora L. Costa',
#   'article_url': 'https://en.wikipedia.org/wiki/Dora_L._Costa'},
#  {'name': 'Edmilson Costa',
#   'article_url': 'https://en.wikipedia.org/wiki/Edmilson_Costa'},
#  {'name': 'Christopher Coyne',
#   'article_url': 'https://en.wikipedia.org/wiki/Christopher_Coyne_(professor)'},
#  {'name': 'Tyler Cowen',
#   'article_url': 'https://en.wikipedia.org/wiki/Tyler_Cowen'},
#  {'name': 'Vincent Crawford',
#   'article_url': 'https://en.wikipedia.org/wiki/Vincent_Crawford'},
#  {'name': 'August Friedrich Wilhelm Crome',
#   'article_url': 'https://en.wikipedia.org/wiki/August_Friedrich_Wilhelm_Crome'},
#  {'name': 'James Crotty',
#   'article_url': 'https://en.wikipedia.org/wiki/James_Crotty_(economist)'},
#  {'name': 'Raymond Crotty',
#   'article_url': 'https://en.wikipedia.org/wiki/Raymond_Crotty'},
#  {'name': 'Benoit Crutzen',
#   'article_url': 'https://en.wikipedia.org/wiki/Benoit_Crutzen'},
#  {'name': 'Jakša Cvitanić',
#   'article_url': 'https://en.wikipedia.org/wiki/Jak%C5%A1a_Cvitani%C4%87'},
#  {'name': 'Uri Dadush',
#   'article_url': 'https://en.wikipedia.org/wiki/Uri_Dadush'},
#  {'name': 'Hugh Dalton',
#   'article_url': 'https://en.wikipedia.org/wiki/Hugh_Dalton'},
#  {'name': 'Herman Daly',
#   'article_url': 'https://en.wikipedia.org/wiki/Herman_Daly'},
#  {'name': 'George Dantzig',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Dantzig'},
#  {'name': 'William A. "Sandy" Darity Jr.',
#   'article_url': 'https://en.wikipedia.org/wiki/William_A._Darity_Jr.'},
#  {'name': 'Biplab Dasgupta',
#   'article_url': 'https://en.wikipedia.org/wiki/Biplab_Dasgupta'},
#  {'name': 'Partha Dasgupta',
#   'article_url': 'https://en.wikipedia.org/wiki/Partha_Dasgupta'},
#  {'name': 'Charles Davenant',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Davenant'},
#  {'name': 'Paul Davidson',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Davidson_(economist)'},
#  {'name': 'Antony Davies',
#   'article_url': 'https://en.wikipedia.org/wiki/Antony_Davies'},
#  {'name': 'D. J. Davies',
#   'article_url': 'https://en.wikipedia.org/wiki/David_James_Davies'},
#  {'name': 'Lance E. Davis',
#   'article_url': 'https://en.wikipedia.org/wiki/Lance_E._Davis'},
#  {'name': 'Angus Deaton',
#   'article_url': 'https://en.wikipedia.org/wiki/Angus_Deaton'},
#  {'name': 'Gérard Debreu',
#   'article_url': 'https://en.wikipedia.org/wiki/G%C3%A9rard_Debreu'},
#  {'name': 'Rajeev Dehejia',
#   'article_url': 'https://en.wikipedia.org/wiki/Rajeev_Dehejia'},
#  {'name': 'J. Bradford DeLong',
#   'article_url': 'https://en.wikipedia.org/wiki/J._Bradford_DeLong'},
#  {'name': 'Harold Demsetz',
#   'article_url': 'https://en.wikipedia.org/wiki/Harold_Demsetz'},
#  {'name': 'Isaac de Pinto',
#   'article_url': 'https://en.wikipedia.org/wiki/Isaac_de_Pinto'},
#  {'name': 'Meghnad Desai, Baron Desai',
#   'article_url': 'https://en.wikipedia.org/wiki/Meghnad_Desai,_Baron_Desai'},
#  {'name': 'Hernando de Soto Polar',
#   'article_url': 'https://en.wikipedia.org/wiki/Hernando_de_Soto_Polar'},
#  {'name': 'Pat Devine',
#   'article_url': 'https://en.wikipedia.org/wiki/Pat_Devine'},
#  {'name': 'Mathias Dewatripont',
#   'article_url': 'https://en.wikipedia.org/wiki/Mathias_Dewatripont'},
#  {'name': 'Armando Di Filippo',
#   'article_url': 'https://en.wikipedia.org/wiki/Armando_Di_Filippo'},
#  {'name': 'Douglas Diamond',
#   'article_url': 'https://en.wikipedia.org/wiki/Douglas_Diamond'},
#  {'name': 'Peter Diamond',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Diamond'},
#  {'name': 'Gladys Dickason',
#   'article_url': 'https://en.wikipedia.org/wiki/Gladys_Dickason'},
#  {'name': 'Peter Dicken',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Dicken'},
#  {'name': 'Benjamin Diokno',
#   'article_url': 'https://en.wikipedia.org/wiki/Benjamin_Diokno'},
#  {'name': 'Avinash Dixit',
#   'article_url': 'https://en.wikipedia.org/wiki/Avinash_Dixit'},
#  {'name': 'Huw Dixon',
#   'article_url': 'https://en.wikipedia.org/wiki/Huw_Dixon'},
#  {'name': 'Peter Dixon',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Dixon_(economist)'},
#  {'name': 'Simeon Djankov',
#   'article_url': 'https://en.wikipedia.org/wiki/Simeon_Djankov'},
#  {'name': 'Maurice Dobb',
#   'article_url': 'https://en.wikipedia.org/wiki/Maurice_Dobb'},
#  {'name': 'David Dodd',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Dodd'},
#  {'name': 'Randall Dodd',
#   'article_url': 'https://en.wikipedia.org/wiki/Randall_Dodd'},
#  {'name': 'Jennifer Doleac',
#   'article_url': 'https://en.wikipedia.org/wiki/Jennifer_Doleac'},
#  {'name': 'Evsey Domar',
#   'article_url': 'https://en.wikipedia.org/wiki/Evsey_Domar'},
#  {'name': 'Paul Donovan',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Donovan_(economist)'},
#  {'name': 'Stephen J. Dubner',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephen_J._Dubner'},
#  {'name': 'Henda Ducados',
#   'article_url': 'https://en.wikipedia.org/wiki/Henda_Ducados'},
#  {'name': 'Esther Duflo',
#   'article_url': 'https://en.wikipedia.org/wiki/Esther_Duflo'},
#  {'name': 'Steven N. Durlauf',
#   'article_url': 'https://en.wikipedia.org/wiki/Steven_N._Durlauf'},
#  {'name': 'Philip H. Dybvig',
#   'article_url': 'https://en.wikipedia.org/wiki/Philip_H._Dybvig'},
#  {'name': 'Shlomo Eckstein',
#   'article_url': 'https://en.wikipedia.org/wiki/Shlomo_Eckstein'},
#  {'name': 'Nicholas Economides',
#   'article_url': 'https://en.wikipedia.org/wiki/Nicholas_Economides'},
#  {'name': 'Francis Ysidro Edgeworth',
#   'article_url': 'https://en.wikipedia.org/wiki/Francis_Ysidro_Edgeworth'},
#  {'name': 'Sebastian Edwards',
#   'article_url': 'https://en.wikipedia.org/wiki/Sebastian_Edwards'},
#  {'name': 'Martin Eichenbaum',
#   'article_url': 'https://en.wikipedia.org/wiki/Martin_Eichenbaum'},
#  {'name': 'Barry Eichengreen',
#   'article_url': 'https://en.wikipedia.org/wiki/Barry_Eichengreen'},
#  {'name': 'Alfred Eichner',
#   'article_url': 'https://en.wikipedia.org/wiki/Alfred_Eichner'},
#  {'name': 'Ali M. El-Agraa',
#   'article_url': 'https://en.wikipedia.org/wiki/Ali_M._El-Agraa'},
#  {'name': 'Daniel Ellsberg',
#   'article_url': 'https://en.wikipedia.org/wiki/Daniel_Ellsberg'},
#  {'name': 'Richard T. Ely',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_T._Ely'},
#  {'name': 'Kenneth G. Elzinga',
#   'article_url': 'https://en.wikipedia.org/wiki/Kenneth_G._Elzinga'},
#  {'name': 'Ernst Engel',
#   'article_url': 'https://en.wikipedia.org/wiki/Ernst_Engel'},
#  {'name': 'Friedrich Engels',
#   'article_url': 'https://en.wikipedia.org/wiki/Friedrich_Engels'},
#  {'name': 'Stanley Engerman',
#   'article_url': 'https://en.wikipedia.org/wiki/Stanley_Engerman'},
#  {'name': 'Robert F. Engle',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_F._Engle'},
#  {'name': 'Ludwig Erhard',
#   'article_url': 'https://en.wikipedia.org/wiki/Ludwig_Erhard'},
#  {'name': 'Vanessa Erogbogbo',
#   'article_url': 'https://en.wikipedia.org/wiki/Vanessa_Erogbogbo'},
#  {'name': 'José Luís Espert',
#   'article_url': 'https://en.wikipedia.org/wiki/Jos%C3%A9_Luis_Espert'},
#  {'name': 'Miren Etxezarreta',
#   'article_url': 'https://en.wikipedia.org/wiki/Miren_Etxezarreta'},
#  {'name': 'Marc Faber',
#   'article_url': 'https://en.wikipedia.org/wiki/Marc_Faber'},
#  {'name': 'Armin Falk',
#   'article_url': 'https://en.wikipedia.org/wiki/Armin_Falk'},
#  {'name': 'Günter Faltin',
#   'article_url': 'https://en.wikipedia.org/wiki/G%C3%BCnter_Faltin'},
#  {'name': 'Eugene Fama',
#   'article_url': 'https://en.wikipedia.org/wiki/Eugene_Fama'},
#  {'name': 'Emmanuel Farhi',
#   'article_url': 'https://en.wikipedia.org/wiki/Emmanuel_Farhi'},
#  {'name': 'M. J. Farrell',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_James_Farrell'},
#  {'name': 'Jeff Faux',
#   'article_url': 'https://en.wikipedia.org/wiki/Jeff_Faux'},
#  {'name': 'Henry Fawcett',
#   'article_url': 'https://en.wikipedia.org/wiki/Henry_Fawcett'},
#  {'name': 'Nikolay Fedorenko',
#   'article_url': 'https://en.wikipedia.org/wiki/Nikolay_Fedorenko'},
#  {'name': 'Ernst Fehr',
#   'article_url': 'https://en.wikipedia.org/wiki/Ernst_Fehr'},
#  {'name': 'Martin Feldstein',
#   'article_url': 'https://en.wikipedia.org/wiki/Martin_Feldstein'},
#  {'name': 'Edgar Fiedler',
#   'article_url': 'https://en.wikipedia.org/wiki/Edgar_Fiedler'},
#  {'name': 'Randall K. Filer',
#   'article_url': 'https://en.wikipedia.org/wiki/Randall_K._Filer'},
#  {'name': 'Amy Finkelstein',
#   'article_url': 'https://en.wikipedia.org/wiki/Amy_Finkelstein'},
#  {'name': 'Stanley Fischer',
#   'article_url': 'https://en.wikipedia.org/wiki/Stanley_Fischer'},
#  {'name': 'Price V. Fishback',
#   'article_url': 'https://en.wikipedia.org/wiki/Price_V._Fishback'},
#  {'name': 'Irving Fisher',
#   'article_url': 'https://en.wikipedia.org/wiki/Irving_Fisher'},
#  {'name': 'Jon Fisher',
#   'article_url': 'https://en.wikipedia.org/wiki/Jon_Fisher'},
#  {'name': 'Jean-Paul Fitoussi',
#   'article_url': 'https://en.wikipedia.org/wiki/Jean-Paul_Fitoussi'},
#  {'name': 'William Fleetwood',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Fleetwood'},
#  {'name': 'Marcus Fleming',
#   'article_url': 'https://en.wikipedia.org/wiki/Marcus_Fleming'},
#  {'name': 'Amelia Fletcher',
#   'article_url': 'https://en.wikipedia.org/wiki/Amelia_Fletcher'},
#  {'name': 'John E. Floyd',
#   'article_url': 'https://en.wikipedia.org/wiki/John_E._Floyd'},
#  {'name': 'Karnit Flug',
#   'article_url': 'https://en.wikipedia.org/wiki/Karnit_Flug'},
#  {'name': 'Robert Fogel',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Fogel'},
#  {'name': 'Foster and Catchings',
#   'article_url': 'https://en.wikipedia.org/wiki/Foster_and_Catchings'},
#  {'name': 'Charles Fourier',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Fourier'},
#  {'name': 'Joseph Francois',
#   'article_url': 'https://en.wikipedia.org/wiki/Joseph_Francois_(economist)'},
#  {'name': 'Robert H. Frank',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_H._Frank'},
#  {'name': 'Jeffrey Frankel',
#   'article_url': 'https://en.wikipedia.org/wiki/Jeffrey_Frankel'},
#  {'name': 'Bernie Fraser',
#   'article_url': 'https://en.wikipedia.org/wiki/Bernie_Fraser_(economist)'},
#  {'name': 'Christopher Freeman',
#   'article_url': 'https://en.wikipedia.org/wiki/Christopher_Freeman'},
#  {'name': 'Richard B. Freeman',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_B._Freeman'},
#  {'name': 'Bruno Frey',
#   'article_url': 'https://en.wikipedia.org/wiki/Bruno_Frey'},
#  {'name': 'Benjamin M. Friedman',
#   'article_url': 'https://en.wikipedia.org/wiki/Benjamin_M._Friedman'},
#  {'name': 'David D. Friedman',
#   'article_url': 'https://en.wikipedia.org/wiki/David_D._Friedman'},
#  {'name': 'Milton Friedman',
#   'article_url': 'https://en.wikipedia.org/wiki/Milton_Friedman'},
#  {'name': 'Rose Friedman',
#   'article_url': 'https://en.wikipedia.org/wiki/Rose_Friedman'},
#  {'name': 'Ragnar Anton Kittil Frisch',
#   'article_url': 'https://en.wikipedia.org/wiki/Ragnar_Anton_Kittil_Frisch'},
#  {'name': 'Roland Fryer',
#   'article_url': 'https://en.wikipedia.org/wiki/Roland_Fryer'},
#  {'name': 'Drew Fudenberg',
#   'article_url': 'https://en.wikipedia.org/wiki/Drew_Fudenberg'},
#  {'name': 'Masahisa Fujita',
#   'article_url': 'https://en.wikipedia.org/wiki/Masahisa_Fujita'},
#  {'name': 'Connel Fullenkamp',
#   'article_url': 'https://en.wikipedia.org/wiki/Connel_Fullenkamp'},
#  {'name': 'Jason Furman',
#   'article_url': 'https://en.wikipedia.org/wiki/Jason_Furman'},
#  {'name': 'Celso Furtado',
#   'article_url': 'https://en.wikipedia.org/wiki/Celso_Furtado'},
#  {'name': 'Xavier Gabaix',
#   'article_url': 'https://en.wikipedia.org/wiki/Xavier_Gabaix'},
#  {'name': 'Yegor Gaidar',
#   'article_url': 'https://en.wikipedia.org/wiki/Yegor_Gaidar'},
#  {'name': 'James Kenneth Galbraith',
#   'article_url': 'https://en.wikipedia.org/wiki/James_K._Galbraith'},
#  {'name': 'John Kenneth Galbraith',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Kenneth_Galbraith'},
#  {'name': 'David Gale',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Gale'},
#  {'name': 'William G. Gale',
#   'article_url': 'https://en.wikipedia.org/wiki/William_G._Gale'},
#  {'name': 'Jordi Galí',
#   'article_url': 'https://en.wikipedia.org/wiki/Jordi_Gal%C3%AD'},
#  {'name': 'A. Ronald Gallant',
#   'article_url': 'https://en.wikipedia.org/wiki/A._Ronald_Gallant'},
#  {'name': 'Mauro Gallegati',
#   'article_url': 'https://en.wikipedia.org/wiki/Mauro_Gallegati'},
#  {'name': 'Oded Galor',
#   'article_url': 'https://en.wikipedia.org/wiki/Oded_Galor'},
#  {'name': 'Francisco Javier Carrillo Gamboa',
#   'article_url': 'https://en.wikipedia.org/wiki/Francisco_Javier_Carrillo_Gamboa'},
#  {'name': 'László Garai',
#   'article_url': 'https://en.wikipedia.org/wiki/L%C3%A1szl%C3%B3_Garai'},
#  {'name': 'Gonzalo Garland',
#   'article_url': 'https://en.wikipedia.org/wiki/Gonzalo_Garland'},
#  {'name': 'Pierangelo Garegnani',
#   'article_url': 'https://en.wikipedia.org/wiki/Pierangelo_Garegnani'},
#  {'name': 'Norton Garfinkle',
#   'article_url': 'https://en.wikipedia.org/wiki/Norton_Garfinkle'},
#  {'name': 'Leonid Gatovsky',
#   'article_url': 'https://en.wikipedia.org/wiki/Leonid_Gatovsky'},
#  {'name': 'John Geanakoplos',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Geanakoplos'},
#  {'name': 'Jacques Généreux',
#   'article_url': 'https://en.wikipedia.org/wiki/Jacques_G%C3%A9n%C3%A9reux'},
#  {'name': 'Henry George',
#   'article_url': 'https://en.wikipedia.org/wiki/Henry_George'},
#  {'name': 'Nicholas Georgescu-Roegen',
#   'article_url': 'https://en.wikipedia.org/wiki/Nicholas_Georgescu-Roegen'},
#  {'name': 'Mark Gertler',
#   'article_url': 'https://en.wikipedia.org/wiki/Mark_Gertler_(economist)'},
#  {'name': 'Silvio Gesell',
#   'article_url': 'https://en.wikipedia.org/wiki/Silvio_Gesell'},
#  {'name': 'Jayati Ghosh',
#   'article_url': 'https://en.wikipedia.org/wiki/Jayati_Ghosh'},
#  {'name': 'Eric Ghysels',
#   'article_url': 'https://en.wikipedia.org/wiki/Eric_Ghysels'},
#  {'name': 'Francesco Giavazzi',
#   'article_url': 'https://en.wikipedia.org/wiki/Francesco_Giavazzi'},
#  {'name': 'Charles Gide',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Gide'},
#  {'name': 'George Gilder',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Gilder'},
#  {'name': 'Richard T. Gill',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_T._Gill'},
#  {'name': 'Victor Ginsburgh',
#   'article_url': 'https://en.wikipedia.org/wiki/Victor_Ginsburgh'},
#  {'name': 'Herbert Gintis',
#   'article_url': 'https://en.wikipedia.org/wiki/Herbert_Gintis'},
#  {'name': 'Edward Glaeser',
#   'article_url': 'https://en.wikipedia.org/wiki/Edward_Glaeser'},
#  {'name': 'Rachel Glennerster',
#   'article_url': 'https://en.wikipedia.org/wiki/Rachel_Glennerster'},
#  {'name': 'Andrew Glyn',
#   'article_url': 'https://en.wikipedia.org/wiki/Andrew_Glyn'},
#  {'name': 'William Godwin',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Godwin'},
#  {'name': 'Claudia Goldin',
#   'article_url': 'https://en.wikipedia.org/wiki/Claudia_Goldin'},
#  {'name': 'Ian Goldin',
#   'article_url': 'https://en.wikipedia.org/wiki/Ian_Goldin'},
#  {'name': 'Jose Antonio Gomariz',
#   'article_url': 'https://en.wikipedia.org/wiki/Jose_Antonio_Gomariz'},
#  {'name': 'Charles Goodhart',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Goodhart'},
#  {'name': 'George Goodman',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Goodman'},
#  {'name': 'Austan Goolsbee',
#   'article_url': 'https://en.wikipedia.org/wiki/Austan_Goolsbee'},
#  {'name': 'Gita Gopinath',
#   'article_url': 'https://en.wikipedia.org/wiki/Gita_Gopinath'},
#  {'name': 'Myron J. Gordon',
#   'article_url': 'https://en.wikipedia.org/wiki/Myron_J._Gordon'},
#  {'name': 'Robert J. Gordon',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_J._Gordon'},
#  {'name': 'Gary Gorton',
#   'article_url': 'https://en.wikipedia.org/wiki/Gary_Gorton'},
#  {'name': 'Hermann Heinrich Gossen',
#   'article_url': 'https://en.wikipedia.org/wiki/Hermann_Heinrich_Gossen'},
#  {'name': 'Christian Gouriéroux',
#   'article_url': 'https://en.wikipedia.org/wiki/Christian_Gouri%C3%A9roux'},
#  {'name': 'Benjamin Graham',
#   'article_url': 'https://en.wikipedia.org/wiki/Benjamin_Graham'},
#  {'name': 'Phil Gramm',
#   'article_url': 'https://en.wikipedia.org/wiki/Phil_Gramm'},
#  {'name': 'Clive Granger',
#   'article_url': 'https://en.wikipedia.org/wiki/Clive_Granger'},
#  {'name': 'George Grantham',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Grantham_(economic_historian)'},
#  {'name': 'William Greene',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Greene_(economist)'},
#  {'name': 'Alan Greenspan',
#   'article_url': 'https://en.wikipedia.org/wiki/Alan_Greenspan'},
#  {'name': 'Thomas Gresham',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_Gresham'},
#  {'name': 'Stephany Griffith-Jones',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephany_Griffith-Jones'},
#  {'name': 'Zvi Griliches',
#   'article_url': 'https://en.wikipedia.org/wiki/Zvi_Griliches'},
#  {'name': 'Elgin Groseclose',
#   'article_url': 'https://en.wikipedia.org/wiki/Elgin_Groseclose'},
#  {'name': 'Gene Grossman',
#   'article_url': 'https://en.wikipedia.org/wiki/Gene_Grossman'},
#  {'name': 'Henryk Grossman',
#   'article_url': 'https://en.wikipedia.org/wiki/Henryk_Grossman'},
#  {'name': 'Jonathan Gruber',
#   'article_url': 'https://en.wikipedia.org/wiki/Jonathan_Gruber_(economist)'},
#  {'name': 'Rebeca Grynspan',
#   'article_url': 'https://en.wikipedia.org/wiki/Rebeca_Grynspan'},
#  {'name': 'Gu Zhun', 'article_url': 'https://en.wikipedia.org/wiki/Gu_Zhun'},
#  {'name': 'Dominique Guellec',
#   'article_url': 'https://en.wikipedia.org/wiki/Dominique_Guellec'},
#  {'name': 'Maria-Carmen Guisan',
#   'article_url': 'https://en.wikipedia.org/wiki/Maria-Carmen_Guisan'},
#  {'name': 'Faruk Gül',
#   'article_url': 'https://en.wikipedia.org/wiki/Faruk_G%C3%BCl'},
#  {'name': 'Trygve Haavelmo',
#   'article_url': 'https://en.wikipedia.org/wiki/Trygve_Haavelmo'},
#  {'name': 'Gottfried Haberler',
#   'article_url': 'https://en.wikipedia.org/wiki/Gottfried_Haberler'},
#  {'name': 'Charles Hall',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Hall_(economist)'},
#  {'name': 'Robert Hall',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Hall_(economist)'},
#  {'name': 'Andrew Hughes Hallett',
#   'article_url': 'https://en.wikipedia.org/wiki/Andrew_Hughes_Hallett'},
#  {'name': 'John Haltiwanger',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Haltiwanger'},
#  {'name': 'Daniel S. Hamermesh',
#   'article_url': 'https://en.wikipedia.org/wiki/Daniel_S._Hamermesh'},
#  {'name': 'James D. Hamilton',
#   'article_url': 'https://en.wikipedia.org/wiki/James_D._Hamilton'},
#  {'name': 'Steve H. Hanke',
#   'article_url': 'https://en.wikipedia.org/wiki/Steve_H._Hanke'},
#  {'name': 'Alvin Hansen',
#   'article_url': 'https://en.wikipedia.org/wiki/Alvin_Hansen'},
#  {'name': 'Lars Peter Hansen',
#   'article_url': 'https://en.wikipedia.org/wiki/Lars_Peter_Hansen'},
#  {'name': 'Peter Reinhard Hansen',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Reinhard_Hansen'},
#  {'name': 'Eric Hanushek',
#   'article_url': 'https://en.wikipedia.org/wiki/Eric_Hanushek'},
#  {'name': 'Mahbub ul Haq',
#   'article_url': 'https://en.wikipedia.org/wiki/Mahbub_ul_Haq'},
#  {'name': 'Arnold Harberger',
#   'article_url': 'https://en.wikipedia.org/wiki/Arnold_Harberger'},
#  {'name': 'Tim Harford',
#   'article_url': 'https://en.wikipedia.org/wiki/Tim_Harford'},
#  {'name': 'Charles Knickerbocker Harley',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Knickerbocker_Harley'},
#  {'name': 'Stephen Harper',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephen_Harper'},
#  {'name': 'Roy Harrod',
#   'article_url': 'https://en.wikipedia.org/wiki/Roy_Harrod'},
#  {'name': 'John Harsanyi',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Harsanyi'},
#  {'name': 'Oliver Hart',
#   'article_url': 'https://en.wikipedia.org/wiki/Oliver_Hart_(economist)'},
#  {'name': 'Campbell Harvey',
#   'article_url': 'https://en.wikipedia.org/wiki/Campbell_Harvey'},
#  {'name': 'Jerry A. Hausman',
#   'article_url': 'https://en.wikipedia.org/wiki/Jerry_A._Hausman'},
#  {'name': 'Bohdan Hawrylyshyn',
#   'article_url': 'https://en.wikipedia.org/wiki/Bohdan_Hawrylyshyn'},
#  {'name': 'Friedrich Hayek',
#   'article_url': 'https://en.wikipedia.org/wiki/Friedrich_Hayek'},
#  {'name': 'Henry Hazlitt',
#   'article_url': 'https://en.wikipedia.org/wiki/Henry_Hazlitt'},
#  {'name': 'James Heckman',
#   'article_url': 'https://en.wikipedia.org/wiki/James_Heckman'},
#  {'name': 'Eli Heckscher',
#   'article_url': 'https://en.wikipedia.org/wiki/Eli_Heckscher'},
#  {'name': 'Robert Heilbroner',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Heilbroner'},
#  {'name': 'Carolyn Heinrich',
#   'article_url': 'https://en.wikipedia.org/wiki/Carolyn_Heinrich'},
#  {'name': 'Christian Hellwig',
#   'article_url': 'https://en.wikipedia.org/wiki/Christian_Hellwig'},
#  {'name': 'Elhanan Helpman',
#   'article_url': 'https://en.wikipedia.org/wiki/Elhanan_Helpman'},
#  {'name': 'Hazel Henderson',
#   'article_url': 'https://en.wikipedia.org/wiki/Hazel_Henderson'},
#  {'name': 'David Forbes Hendry',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Forbes_Hendry'},
#  {'name': 'Peter Blair Henry',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Blair_Henry'},
#  {'name': 'Noreena Hertz',
#   'article_url': 'https://en.wikipedia.org/wiki/Noreena_Hertz'},
#  {'name': 'William Hewins',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Hewins'},
#  {'name': 'John Hicks',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Hicks'},
#  {'name': 'Michael J. Hicks',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_J._Hicks'},
#  {'name': 'Robert Higgs',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Higgs'},
#  {'name': 'Rudolf Hilferding',
#   'article_url': 'https://en.wikipedia.org/wiki/Rudolf_Hilferding'},
#  {'name': 'Jack Hirshleifer',
#   'article_url': 'https://en.wikipedia.org/wiki/Jack_Hirshleifer'},
#  {'name': 'John A. Hobson',
#   'article_url': 'https://en.wikipedia.org/wiki/John_A._Hobson'},
#  {'name': 'Thomas Hodgskin',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_Hodgskin'},
#  {'name': 'Samuel Hollander',
#   'article_url': 'https://en.wikipedia.org/wiki/Samuel_Hollander'},
#  {'name': 'Bengt Holmström',
#   'article_url': 'https://en.wikipedia.org/wiki/Bengt_Holmstr%C3%B6m'},
#  {'name': 'Charles A. Holt',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_A._Holt'},
#  {'name': 'Harry J. Holzer',
#   'article_url': 'https://en.wikipedia.org/wiki/Harry_J._Holzer'},
#  {'name': 'Kevin Hoover',
#   'article_url': 'https://en.wikipedia.org/wiki/Kevin_Hoover'},
#  {'name': 'Hans-Hermann Hoppe',
#   'article_url': 'https://en.wikipedia.org/wiki/Hans-Hermann_Hoppe'},
#  {'name': 'Charles Horioka',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Horioka'},
#  {'name': 'Branko Horvat',
#   'article_url': 'https://en.wikipedia.org/wiki/Branko_Horvat'},
#  {'name': 'Harold Hotelling',
#   'article_url': 'https://en.wikipedia.org/wiki/Harold_Hotelling'},
#  {'name': 'Hendrik S. Houthakker',
#   'article_url': 'https://en.wikipedia.org/wiki/Hendrik_S._Houthakker'},
#  {'name': 'Peter Howitt',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Howitt_(economist)'},
#  {'name': 'Elizabeth Ellis Hoyt',
#   'article_url': 'https://en.wikipedia.org/wiki/Elizabeth_Ellis_Hoyt'},
#  {'name': 'William Hsiao',
#   'article_url': 'https://en.wikipedia.org/wiki/William_Hsiao'},
#  {'name': 'Yukon Huang',
#   'article_url': 'https://en.wikipedia.org/wiki/Yukon_Huang'},
#  {'name': 'Glenn Hubbard',
#   'article_url': 'https://en.wikipedia.org/wiki/Glenn_Hubbard_(economist)'},
#  {'name': 'Michael Hudson',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Hudson_(economist)'},
#  {'name': 'Jesús Huerta de Soto',
#   'article_url': 'https://en.wikipedia.org/wiki/Jes%C3%BAs_Huerta_de_Soto'},
#  {'name': 'David Hume',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Hume'},
#  {'name': 'Thomas M. Humphrey',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_M._Humphrey'},
#  {'name': 'Jennifer Hunt',
#   'article_url': 'https://en.wikipedia.org/wiki/Jennifer_Hunt'},
#  {'name': 'Leonid Hurwicz',
#   'article_url': 'https://en.wikipedia.org/wiki/Leonid_Hurwicz'},
#  {'name': 'Terence Wilmot Hutchison',
#   'article_url': 'https://en.wikipedia.org/wiki/Terence_Wilmot_Hutchison'},
#  {'name': 'Sri Mulyani Indrawati',
#   'article_url': 'https://en.wikipedia.org/wiki/Sri_Mulyani_Indrawati'},
#  {'name': 'Stefan Ingves',
#   'article_url': 'https://en.wikipedia.org/wiki/Stefan_Ingves'},
#  {'name': 'Jay Inslee',
#   'article_url': 'https://en.wikipedia.org/wiki/Jay_Inslee'},
#  {'name': 'Douglas Irwin',
#   'article_url': 'https://en.wikipedia.org/wiki/Douglas_Irwin'},
#  {'name': 'T. M. Thomas Isaac',
#   'article_url': 'https://en.wikipedia.org/wiki/T._M._Thomas_Isaac'},
#  {'name': 'Mugur Isărescu',
#   'article_url': 'https://en.wikipedia.org/wiki/Mugur_Is%C4%83rescu'},
#  {'name': 'Otmar Issing',
#   'article_url': 'https://en.wikipedia.org/wiki/Otmar_Issing'},
#  {'name': 'Makoto Itoh',
#   'article_url': 'https://en.wikipedia.org/wiki/Makoto_Itoh'},
#  {'name': 'Matthew O. Jackson',
#   'article_url': 'https://en.wikipedia.org/wiki/Matthew_O._Jackson'},
#  {'name': 'Tim Jackson',
#   'article_url': 'https://en.wikipedia.org/wiki/Tim_Jackson_(economist)'},
#  {'name': 'David A. Jaeger',
#   'article_url': 'https://en.wikipedia.org/wiki/David_A._Jaeger'},
#  {'name': 'Davoud Danesh-Jafari',
#   'article_url': 'https://en.wikipedia.org/wiki/Davoud_Danesh-Jafari'},
#  {'name': 'Ravi Jagannathan',
#   'article_url': 'https://en.wikipedia.org/wiki/Ravi_Jagannathan'},
#  {'name': 'Eliot Janeway',
#   'article_url': 'https://en.wikipedia.org/wiki/Eliot_Janeway'},
# ...
#  {'name': 'Steven Plaut',
#   'article_url': 'https://en.wikipedia.org/wiki/Steven_Plaut'},
#  {'name': 'Charles Plott',
#   'article_url': 'https://en.wikipedia.org/wiki/Charles_Plott'},
#  {'name': 'Serhiy Podolynsky',
#   'article_url': 'https://en.wikipedia.org/wiki/Serhiy_Podolynsky'},
#  {'name': 'Karl Polanyi',
#   'article_url': 'https://en.wikipedia.org/wiki/Karl_Polanyi'},
#  {'name': 'Michael Polanyi',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Polanyi'},
#  {'name': 'Robert Pollin',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Pollin'},
#  {'name': 'Yuri Poluneev',
#   'article_url': 'https://en.wikipedia.org/wiki/Yuri_Poluneev'},
#  {'name': 'Dina Pomeranz',
#   'article_url': 'https://en.wikipedia.org/wiki/Dina_Pomeranz'},
#  {'name': 'Jean-Pierre Ponssard',
#   'article_url': 'https://en.wikipedia.org/wiki/Jean-Pierre_Ponssard'},
#  {'name': 'Gale Pooley',
#   'article_url': 'https://en.wikipedia.org/wiki/Gale_Pooley'},
#  {'name': 'Arden Pope',
#   'article_url': 'https://en.wikipedia.org/wiki/Arden_Pope'},
#  {'name': 'Michael Porter',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Porter'},
#  {'name': 'Richard Portes',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Portes'},
#  {'name': 'Arturo C. Porzecanski',
#   'article_url': 'https://en.wikipedia.org/wiki/Arturo_C._Porzecanski'},
#  {'name': 'Richard Posner',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Posner'},
#  {'name': 'James M. Poterba',
#   'article_url': 'https://en.wikipedia.org/wiki/James_M._Poterba'},
#  {'name': 'Bernard van Praag',
#   'article_url': 'https://en.wikipedia.org/wiki/Bernard_van_Praag'},
#  {'name': 'John W. Pratt',
#   'article_url': 'https://en.wikipedia.org/wiki/John_W._Pratt'},
#  {'name': 'Edward C. Prescott',
#   'article_url': 'https://en.wikipedia.org/wiki/Edward_C._Prescott'},
#  {'name': 'Steven Pressman',
#   'article_url': 'https://en.wikipedia.org/wiki/Steven_Pressman_(economist)'},
#  {'name': 'Clyde V. Prestowitz Jr.',
#   'article_url': 'https://en.wikipedia.org/wiki/Clyde_V._Prestowitz_Jr.'},
#  {'name': 'Raúl Prebisch',
#   'article_url': 'https://en.wikipedia.org/wiki/Ra%C3%BAl_Prebisch'},
#  {'name': 'Yevgeni Preobrazhensky',
#   'article_url': 'https://en.wikipedia.org/wiki/Yevgeni_Preobrazhensky'},
#  {'name': 'Cuno Pümpin',
#   'article_url': 'https://en.wikipedia.org/wiki/Cuno_P%C3%BCmpin'},
#  {'name': 'Guy Quaden',
#   'article_url': 'https://en.wikipedia.org/wiki/Guy_Quaden'},
#  {'name': 'Danny Quah',
#   'article_url': 'https://en.wikipedia.org/wiki/Danny_Quah'},
#  {'name': 'François Quesnay',
#   'article_url': 'https://en.wikipedia.org/wiki/Fran%C3%A7ois_Quesnay'},
#  {'name': 'John Quiggin',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Quiggin'},
#  {'name': 'Matthew Rabin',
#   'article_url': 'https://en.wikipedia.org/wiki/Matthew_Rabin'},
#  {'name': 'Roy Radner',
#   'article_url': 'https://en.wikipedia.org/wiki/Roy_Radner'},
#  {'name': 'John Rae',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Rae_(economist)'},
#  {'name': 'Richard W. Rahn',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_W._Rahn'},
#  {'name': 'Raghuram Rajan',
#   'article_url': 'https://en.wikipedia.org/wiki/Raghuram_Rajan'},
#  {'name': 'Mihir Rakshit',
#   'article_url': 'https://en.wikipedia.org/wiki/Mihir_Rakshit'},
#  {'name': 'Rogelio Ramírez de la O',
#   'article_url': 'https://en.wikipedia.org/wiki/Rogelio_Ram%C3%ADrez_de_la_O'},
#  {'name': 'Frank Plumpton Ramsey',
#   'article_url': 'https://en.wikipedia.org/wiki/Frank_Plumpton_Ramsey'},
#  {'name': 'Ajit Ranade',
#   'article_url': 'https://en.wikipedia.org/wiki/Ajit_Ranade'},
#  {'name': 'Leonard Rapping',
#   'article_url': 'https://en.wikipedia.org/wiki/Leonard_Rapping'},
#  {'name': 'Martin Ravallion',
#   'article_url': 'https://en.wikipedia.org/wiki/Martin_Ravallion'},
#  {'name': 'Debra Ray',
#   'article_url': 'https://en.wikipedia.org/wiki/Debraj_Ray_(economist)'},
#  {'name': 'Daniel Raymond',
#   'article_url': 'https://en.wikipedia.org/wiki/Daniel_Raymond'},
#  {'name': 'Riccardo Realfonzo',
#   'article_url': 'https://en.wikipedia.org/wiki/Riccardo_Realfonzo'},
#  {'name': 'Ralph Recto',
#   'article_url': 'https://en.wikipedia.org/wiki/Ralph_Recto'},
#  {'name': 'Daniel Rees',
#   'article_url': 'https://en.wikipedia.org/wiki/Daniel_Rees_(economist)'},
#  {'name': 'Robert Reich',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Reich'},
#  {'name': 'Helmut Reichelt',
#   'article_url': 'https://en.wikipedia.org/wiki/Helmut_Reichelt'},
#  {'name': 'Carmen Reinhart',
#   'article_url': 'https://en.wikipedia.org/wiki/Carmen_Reinhart'},
#  {'name': 'Ricardo Reis',
#   'article_url': 'https://en.wikipedia.org/wiki/Ricardo_Reis_(economist)'},
#  {'name': 'George Reisman',
#   'article_url': 'https://en.wikipedia.org/wiki/George_Reisman'},
#  {'name': 'Philip J. Reny',
#   'article_url': 'https://en.wikipedia.org/wiki/Philip_J._Reny'},
#  {'name': 'Stephen Resnick',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephen_Resnick'},
#  {'name': 'David Ricardo',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Ricardo'},
#  {'name': 'Matthew Richardson',
#   'article_url': 'https://en.wikipedia.org/wiki/Matthew_Richardson_(economist)'},
#  {'name': 'Frank-Jürgen Richter',
#   'article_url': 'https://en.wikipedia.org/wiki/Frank-J%C3%BCrgen_Richter'},
#  {'name': 'Jeremy Rifkin',
#   'article_url': 'https://en.wikipedia.org/wiki/Jeremy_Rifkin'},
#  {'name': 'Alice Rivlin',
#   'article_url': 'https://en.wikipedia.org/wiki/Alice_Rivlin'},
#  {'name': 'Lionel Robbins',
#   'article_url': 'https://en.wikipedia.org/wiki/Lionel_Robbins'},
#  {'name': 'Donald John Roberts',
#   'article_url': 'https://en.wikipedia.org/wiki/Donald_John_Roberts'},
#  {'name': 'Paul Craig Roberts',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Craig_Roberts'},
#  {'name': 'Russ Roberts',
#   'article_url': 'https://en.wikipedia.org/wiki/Russ_Roberts'},
#  {'name': 'Denis Robertson',
#   'article_url': 'https://en.wikipedia.org/wiki/Dennis_Robertson_(economist)'},
#  {'name': 'Abraham Robinson',
#   'article_url': 'https://en.wikipedia.org/wiki/Abraham_Robinson'},
#  {'name': 'Austin Robinson',
#   'article_url': 'https://en.wikipedia.org/wiki/Austin_Robinson'},
#  {'name': 'Joan Robinson',
#   'article_url': 'https://en.wikipedia.org/wiki/Joan_Robinson'},
#  {'name': 'Johann Karl Rodbertus',
#   'article_url': 'https://en.wikipedia.org/wiki/Johann_Karl_Rodbertus'},
#  {'name': 'Dani Rodrik',
#   'article_url': 'https://en.wikipedia.org/wiki/Dani_Rodrik'},
#  {'name': 'John Roemer',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Roemer'},
#  {'name': 'Kenneth Rogoff',
#   'article_url': 'https://en.wikipedia.org/wiki/Kenneth_Rogoff'},
#  {'name': 'Gérard Roland',
#   'article_url': 'https://en.wikipedia.org/wiki/G%C3%A9rard_Roland_(economist)'},
#  {'name': 'Eric Roll',
#   'article_url': 'https://en.wikipedia.org/wiki/Eric_Roll'},
#  {'name': 'Richard Roll',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Roll'},
#  {'name': 'Christina Romer',
#   'article_url': 'https://en.wikipedia.org/wiki/Christina_Romer'},
#  {'name': 'David Romer',
#   'article_url': 'https://en.wikipedia.org/wiki/David_Romer'},
#  {'name': 'Paul Romer',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Romer'},
#  {'name': 'Alessandro Roncaglia',
#   'article_url': 'https://en.wikipedia.org/wiki/Alessandro_Roncaglia'},
#  {'name': 'Ivar Rooth',
#   'article_url': 'https://en.wikipedia.org/wiki/Ivar_Rooth'},
#  {'name': 'Raymond de Roover',
#   'article_url': 'https://en.wikipedia.org/wiki/Raymond_de_Roover'},
#  {'name': 'Harvey S. Rosen',
#   'article_url': 'https://en.wikipedia.org/wiki/Harvey_S._Rosen'},
#  {'name': 'Henry Rosovsky',
#   'article_url': 'https://en.wikipedia.org/wiki/Henry_Rosovsky'},
#  {'name': 'Sherwin Rosen',
#   'article_url': 'https://en.wikipedia.org/wiki/Sherwin_Rosen'},
#  {'name': 'Nathan Rosenberg',
#   'article_url': 'https://en.wikipedia.org/wiki/Nathan_Rosenberg'},
#  {'name': 'Eric S. Rosengren',
#   'article_url': 'https://en.wikipedia.org/wiki/Eric_S._Rosengren'},
#  {'name': 'Mark Rosenzweig',
#   'article_url': 'https://en.wikipedia.org/wiki/Mark_Rosenzweig_(economist)'},
#  {'name': 'Stephen A. Ross',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephen_Ross_(economist)'},
#  {'name': 'J. Barkley Rosser Jr.',
#   'article_url': 'https://en.wikipedia.org/wiki/J._Barkley_Rosser_Jr.'},
#  {'name': 'Esteban Rossi-Hansberg',
#   'article_url': 'https://en.wikipedia.org/wiki/Esteban_Rossi-Hansberg'},
#  {'name': 'Walt Whitman Rostow',
#   'article_url': 'https://en.wikipedia.org/wiki/Walt_Whitman_Rostow'},
#  {'name': 'Julio Rotemberg',
#   'article_url': 'https://en.wikipedia.org/wiki/Julio_Rotemberg'},
#  {'name': 'Alvin E. Roth',
#   'article_url': 'https://en.wikipedia.org/wiki/Alvin_E._Roth'},
#  {'name': 'Timothy P. Roth',
#   'article_url': 'https://en.wikipedia.org/wiki/Timothy_P._Roth'},
#  {'name': 'Murray Rothbard',
#   'article_url': 'https://en.wikipedia.org/wiki/Murray_Rothbard'},
#  {'name': 'Erwin Rothbarth',
#   'article_url': 'https://en.wikipedia.org/wiki/Erwin_Rothbarth'},
#  {'name': 'Michael Rothschild',
#   'article_url': 'https://en.wikipedia.org/wiki/Michael_Rothschild'},
#  {'name': 'Nouriel Roubini',
#   'article_url': 'https://en.wikipedia.org/wiki/Nouriel_Roubini'},
#  {'name': 'Cecilia Rouse',
#   'article_url': 'https://en.wikipedia.org/wiki/Cecilia_Rouse'},
#  {'name': 'Robert Rowthorn',
#   'article_url': 'https://en.wikipedia.org/wiki/Robert_Rowthorn'},
#  {'name': 'Heather Royer',
#   'article_url': 'https://en.wikipedia.org/wiki/Heather_Royer'},
#  {'name': 'Scott Rozelle',
#   'article_url': 'https://en.wikipedia.org/wiki/Scott_Rozelle'},
#  {'name': 'Isaak Illich Rubin',
#   'article_url': 'https://en.wikipedia.org/wiki/Isaak_Illich_Rubin'},
#  {'name': 'Paul Rubin',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Rubin'},
#  {'name': 'Daniel L. Rubinfeld',
#   'article_url': 'https://en.wikipedia.org/wiki/Daniel_L._Rubinfeld'},
#  {'name': 'Ariel Rubinstein',
#   'article_url': 'https://en.wikipedia.org/wiki/Ariel_Rubinstein'},
#  {'name': 'Richard Rumelt',
#   'article_url': 'https://en.wikipedia.org/wiki/Richard_Rumelt'},
#  {'name': 'Isaak Russman',
#   'article_url': 'https://en.wikipedia.org/wiki/Isaak_Russman'},
#  {'name': 'John Rust',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Rust'},
#  {'name': 'Justinian Rweyemamu',
#   'article_url': 'https://en.wikipedia.org/wiki/Justinian_Rweyemamu'},
#  {'name': 'Tadeusz Rybczynski',
#   'article_url': 'https://en.wikipedia.org/wiki/Tadeusz_Rybczynski'},
#  {'name': 'Alfredo Saad-Filho',
#   'article_url': 'https://en.wikipedia.org/wiki/Alfredo_Saad-Filho'},
#  {'name': 'Fabrizio Saccomanni',
#   'article_url': 'https://en.wikipedia.org/wiki/Fabrizio_Saccomanni'},
#  {'name': 'Alexander Sachs',
#   'article_url': 'https://en.wikipedia.org/wiki/Alexander_Sachs'},
#  {'name': 'Jeffrey Sachs',
#   'article_url': 'https://en.wikipedia.org/wiki/Jeffrey_Sachs'},
#  {'name': 'Emmanuel Saez',
#   'article_url': 'https://en.wikipedia.org/wiki/Emmanuel_Saez'},
#  {'name': 'Claudia Sahm',
#   'article_url': 'https://en.wikipedia.org/wiki/Claudia_Sahm'},
#  {'name': 'Gilles Saint-Paul',
#   'article_url': 'https://en.wikipedia.org/wiki/Gilles_Saint-Paul'},
#  {'name': 'Henri de Saint-Simon',
#   'article_url': 'https://en.wikipedia.org/wiki/Claude_Henri_de_Rouvroy,_Comte_de_Saint-Simon'},
#  {'name': 'Xavier Sala i Martin',
#   'article_url': 'https://en.wikipedia.org/wiki/Xavier_Sala-i-Martin'},
#  {'name': 'António de Oliveira Salazar',
#   'article_url': 'https://en.wikipedia.org/wiki/Ant%C3%B3nio_de_Oliveira_Salazar'},
#  {'name': 'Lise Salvas-Bronsard',
#   'article_url': 'https://en.wikipedia.org/wiki/Lise_Salvas-Bronsard'},
#  {'name': 'Arthur Salz',
#   'article_url': 'https://en.wikipedia.org/wiki/Arthur_Salz'},
#  {'name': 'Paul Samuelson',
#   'article_url': 'https://en.wikipedia.org/wiki/Paul_Samuelson'},
#  {'name': 'Chris William Sanchirico',
#   'article_url': 'https://en.wikipedia.org/wiki/Chris_William_Sanchirico'},
#  {'name': 'José Santana',
#   'article_url': 'https://en.wikipedia.org/wiki/Jos%C3%A9_Santana_(economist)'},
#  {'name': 'Diego Abad de Santillán',
#   'article_url': 'https://en.wikipedia.org/wiki/Diego_Abad_de_Santill%C3%A1n'},
#  {'name': 'Juan Manuel Santos',
#   'article_url': 'https://en.wikipedia.org/wiki/Juan_Manuel_Santos'},
#  {'name': 'Theotônio dos Santos',
#   'article_url': 'https://en.wikipedia.org/wiki/Theot%C3%B4nio_dos_Santos'},
#  {'name': 'Gopal Krishna Sarangi',
#   'article_url': 'https://en.wikipedia.org/wiki/Gopal_Krishna_Sarangi'},
#  {'name': 'Thomas J. Sargent',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_J._Sargent'},
#  {'name': 'Mark Satterthwaite',
#   'article_url': 'https://en.wikipedia.org/wiki/Mark_Satterthwaite'},
#  {'name': 'Anthony Saunders',
#   'article_url': 'https://en.wikipedia.org/wiki/Anthony_Saunders_(economist)'},
#  {'name': 'Jean-Baptiste Say',
#   'article_url': 'https://en.wikipedia.org/wiki/Jean-Baptiste_Say'},
#  {'name': 'Louis Auguste Say',
#   'article_url': 'https://en.wikipedia.org/wiki/Louis_Auguste_Say'},
#  {'name': 'Herbert Scarf',
#   'article_url': 'https://en.wikipedia.org/wiki/Herbert_Scarf'},
#  {'name': 'Hjalmar Schacht',
#   'article_url': 'https://en.wikipedia.org/wiki/Hjalmar_Schacht'},
#  {'name': 'Morton O. Schapiro',
#   'article_url': 'https://en.wikipedia.org/wiki/Morton_O._Schapiro'},
#  {'name': 'José Scheinkman',
#   'article_url': 'https://en.wikipedia.org/wiki/Jos%C3%A9_Scheinkman'},
#  {'name': 'Thomas Schelling',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_Schelling'},
#  {'name': 'Peter Schiff',
#   'article_url': 'https://en.wikipedia.org/wiki/Peter_Schiff'},
#  {'name': 'Alexander Schlichter',
#   'article_url': 'https://en.wikipedia.org/wiki/Alexander_Schlichter'},
#  {'name': 'Christoph M. Schmidt',
#   'article_url': 'https://en.wikipedia.org/wiki/Christoph_M._Schmidt'},
#  {'name': 'Helmut Schmidt',
#   'article_url': 'https://en.wikipedia.org/wiki/Helmut_Schmidt'},
#  {'name': 'John Schmitt',
#   'article_url': 'https://en.wikipedia.org/wiki/John_Schmitt_(economist)'},
#  {'name': 'Gustav von Schmoller',
#   'article_url': 'https://en.wikipedia.org/wiki/Gustav_von_Schmoller'},
#  {'name': 'Myron Scholes',
#   'article_url': 'https://en.wikipedia.org/wiki/Myron_Scholes'},
#  {'name': 'Stephan Schulmeister',
#   'article_url': 'https://en.wikipedia.org/wiki/Stephan_Schulmeister'},
#  {'name': 'Theodore Schultz',
#   'article_url': 'https://en.wikipedia.org/wiki/Theodore_Schultz'},
#  {'name': 'Ernst Schumacher',
#   'article_url': 'https://en.wikipedia.org/wiki/E._F._Schumacher'},
#  {'name': 'Joseph Schumpeter',
#   'article_url': 'https://en.wikipedia.org/wiki/Joseph_Schumpeter'},
#  {'name': 'Anna Schwartz',
#   'article_url': 'https://en.wikipedia.org/wiki/Anna_Schwartz'},
#  {'name': 'Anne A. Scitovsky',
#   'article_url': 'https://en.wikipedia.org/wiki/Anne_A._Scitovsky'},
#  {'name': 'Tibor Scitovsky',
#   'article_url': 'https://en.wikipedia.org/wiki/Tibor_Scitovsky'},
#  {'name': 'Molly Scott Cato',
#   'article_url': 'https://en.wikipedia.org/wiki/Molly_Scott_Cato'},
#  {'name': 'Ernesto Screpanti',
#   'article_url': 'https://en.wikipedia.org/wiki/Ernesto_Screpanti'},
#  {'name': 'Jules Sedney',
#   'article_url': 'https://en.wikipedia.org/wiki/Jules_Sedney'},
#  {'name': 'L. William Seidman',
#   'article_url': 'https://en.wikipedia.org/wiki/L._William_Seidman'},
#  {'name': 'Thomas T. Sekine',
#   'article_url': 'https://en.wikipedia.org/wiki/Thomas_T._Sekine'},
#  {'name': 'Arthur Seldon',
#   'article_url': 'https://en.wikipedia.org/wiki/Arthur_Seldon'},
#  {'name': 'Edwin R. A. Seligman',
#   'article_url': 'https://en.wikipedia.org/wiki/Edwin_R._A._Seligman'},
#  {'name': 'Reinhard Selten',
#   'article_url': 'https://en.wikipedia.org/wiki/Reinhard_Selten'},
#  {'name': 'Amartya Sen',
#   'article_url': 'https://en.wikipedia.org/wiki/Amartya_Sen'},
#  {'name': 'Hans Sennholz',
#   'article_url': 'https://en.wikipedia.org/wiki/Hans_Sennholz'},
#  {'name': 'Nassau William Senior',
#   'article_url': 'https://en.wikipedia.org/wiki/Nassau_William_Senior'},
#  {'name': 'Andrew Sentance',
#   'article_url': 'https://en.wikipedia.org/wiki/Andrew_Sentance'},
#  {'name': 'Brad Setser',
#   'article_url': 'https://en.wikipedia.org/wiki/Brad_Setser'},
#  ...]

# %% [markdown]
# Get QID & Summary for each economist using Wikipedia’s API

# %% [markdown]
# Get the summary of each economist to later use that summary to categorize which area of economics they work in.

# %%
def fetch_wiki_api(title):
    """Returns QID and extract summary from Wikipedia API."""
    
    # # Wikipedia requires URL encoding for parentheses, spaces, accents, etc.
    # title = quote(title)
    
    S = requests.Session()
    api_url = "https://en.wikipedia.org/w/api.php"

    params = {
        "action": "query",
        "titles": title,
        "prop": "pageprops|extracts",
        "exintro": True,
        "explaintext": True,
        "format": "json",
    }

    r = S.get(url=api_url, params=params, headers=headers)

    # Check for errors before decoding
    if r.status_code != 200:
        print("HTTP error:", r.status_code, title)
        print(r.text[:200])
        return None, None

    try:
        data = r.json()
    except Exception:
        print("JSON decode error for:", title)
        print(r.text[:300])
        return None, None

    pages = data.get("query", {}).get("pages", {})
    for _, page in pages.items():
        qid = page.get("pageprops", {}).get("wikibase_item", None)
        summary = page.get("extract", "")
        return qid, summary

    return None, ""

# %% [markdown]
# The code below takes around 10 mins to run, results are saved in the csv.

# %%
# Loop through economists

for econ in economists:
    # extract last part of URL as page title
    title = econ["article_url"].split("/wiki/")[1]

    qid, summary = fetch_wiki_api(title)
    econ["qid"] = qid
    econ["summary"] = summary

    time.sleep(0.1)  # avoid hitting API rate limits

df = pd.DataFrame(economists)
df.head()
# Out:
#                  name                                       article_url  \
# 0        Edith Abbott        https://en.wikipedia.org/wiki/Edith_Abbott
# 1      Daron Acemoglu      https://en.wikipedia.org/wiki/Daron_Acemoglu
# 2     Nicola Acocella     https://en.wikipedia.org/wiki/Nicola_Acocella
# 3          Zoltan Acs          https://en.wikipedia.org/wiki/Zoltan_Acs
# 4  Henry Carter Adams  https://en.wikipedia.org/wiki/Henry_Carter_Adams
#
#         qid                                            summary
# 0   Q272731  Edith Abbott (September 26, 1876 – July 28, 19...
# 1   Q718581  Kamer Daron Acemoğlu (born September 3, 1967) ...
# 2  Q7001311  Nicola Acocella (born 3 July 1939) is an Itali...
# 3  Q8073604  Zoltan J. Acs (born 1947) is an American econo...
# 4   Q518021  Henry Carter Adams (December 31, 1851 – August...

# %%
df.to_csv("economists_list_with_summaries.csv", index=False)
